# %% [markdown]
# <a href="https://colab.research.google.com/github/gunil0817/code_archive/blob/master/poolcart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_memory_growth(gpus[0], True)
  except RuntimeError as e:
    # 프로그램 시작시에 메모리 증가가 설정되어야만 합니다
    print(e)

model0 = keras.Sequential(
    [
        keras.Input(shape=(4,)),
        layers.Dense(5, activation="relu"),
        layers.Dense(10, activation="relu"),
        layers.Dense(1,name='output')
    ]
)
model1 = keras.Sequential(
    [
        keras.Input(shape=(4,)),
        layers.Dense(5, activation="relu"),
        layers.Dense(10, activation="relu"),
        layers.Dense(1, name='output')
    ]
)
#, kernel_initializer=keras.initializers.RandomNormal(mean=0.5, stddev=0.05, seed=None)

model0.compile(
    optimizer=keras.optimizers.SGD(learning_rate = 0.001, momentum=0),
    loss=keras.losses.MeanSquaredError(),
    metrics=[keras.metrics.MeanSquaredError()]
)
model1.compile(
    optimizer=keras.optimizers.SGD(learning_rate = 0.001, momentum=0),
    loss=keras.losses.MeanSquaredError(),
    metrics=[keras.metrics.MeanSquaredError()]
)

# %%
import gym
import time
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_memory_growth(gpus[0], True)
  except RuntimeError as e:
    # 프로그램 시작시에 메모리 증가가 설정되어야만 합니다
    print(e)

model = keras.Sequential(
    [
        keras.Input(shape=(4,)),
        layers.Dense(5, activation="relu", kernel_initializer=keras.initializers.RandomNormal(mean=1, stddev=0.1, seed=None)),
        layers.Dense(30, activation="relu", kernel_initializer=keras.initializers.RandomNormal(mean=1, stddev=0.1, seed=None)),
        layers.Dense(2,name='output')
    ]
)

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate = 0.001),
    loss=keras.losses.Huber(delta=1.0),
    metrics=[keras.metrics.MeanSquaredError()]
    )

# Constants
STOP_CRT = 1000
EPSILON = 0.1
DISCOUNT = 0.99
EPOCH = 1000
# Generate Environment
env = gym.make('CartPole-v1')

# For Every Learning Iterations
history = []

best = 0

for l in np.arange(EPOCH):
    state = env.reset()
    state = tf.convert_to_tensor(state)
    state = tf.expand_dims(state, 0)

    num_step = 0
    num_action = np.zeros([2,], dtype=int)
    done = False
    while (not done) and (num_step < STOP_CRT):
        value = model(state)
        #select action
        if np.random.rand(1) < EPSILON:
            action = np.random.randint(0,2)
        else:
            action = np.argmax(value)

        new_state, reward, done, _ = env.step(action)
        new_state = tf.convert_to_tensor(new_state)
        new_state = tf.expand_dims(new_state,0)


        history.append([state, value, action, new_state, int(done)])

        state = new_state
        num_step += 1

    print("Episode : {0} | score : {1} | best : {2} | {3} vs {4}".format(l, num_step, best, int(num_action[0]), int(num_action[1])))
    # Check Max Performance
    if best < num_step :
        best = num_step
    if len(history) > 5000:
        sample_batch = random.sample(history, 32)
        list_state, list_value, list_action, list_new_state, list_done = [], [], [], [], []
        for s, v, a, n_s, d in sample_batch:
            list_state.append(s)
            list_value.append(v)
            list_action.append(a)
            list_new_state.append(n_s)
            list_done.append(d)
        value = 1 + (DISCOUNT * np.amax(model(tf.convert_to_tensor(list_new_state)),2)) *

        # if done:
        #     value = 1
        # else:
        #     value = 1 + DISCOUNT * np.max(model(n_s))
        # target = model(s)
        # target.numpy()[0][a] = value  # unselected action remains same
        # model.fit(s, target, epochs=1, verbose=0)



#
#
# state = env.reset().reshape([-1,4])
#
# print(model(state).numpy())
# print(model1(state).numpy())
# print(model.get_weights())
#
# # Generate Environment
# state = env.reset()
# # For Every Learning Iterations
# done = False
# playtime = 0
# while not done:
#     state = state.reshape([-1, 4])
#     values = np.array([model(state)[0,0],model1(state)[0,0]])
#     action =  np.argmax(values)
#     state, reward, done, info = env.step(action)
#     env.render()
#     time.sleep(0.01)
#     playtime += 1
# print(playtime)
# env.close()

# %%
# Constants
STOP_CRT = 100
TEMP = 1
DISCOUNT = 0.99

# Generate Environment
env = gym.make('CartPole-v1')

# For Every Learning Iterations
state_history = np.zeros((STOP_CRT, 4))
estimated_value_history = np.zeros((STOP_CRT, 2))
action_history = np.zeros((STOP_CRT, 1), dtype=int)

for l in np.arange(100):
    state = env.reset().reshape([-1,4])
    num_step = 0
    num_balanced = 0
    done = False
    #while ((not done) and num_step < 256):
    t = time.time()
    while num_step < STOP_CRT:
        values = np.array([model0(state)[0,0],model1(state)[0,0]])
        #values = np.array([model0(.predict(state)[0,0],model1.predict(state)[0,0]])
        # Select Action
        if np.random.random(1) < (np.exp(values[0] * TEMP) / (np.sum(np.exp(values * TEMP)))):
            action = int(0)
        else:
            action = int(1)
        # Save Current Step
        state_history[num_step,:] = state
        estimated_value_history[num_step,:] = values
        action_history[num_step,0] = action
        # Do Action
        state, reward, done, _ = env.step(action)
        state = state.reshape([-1, 4])
        if not done:
            num_balanced += 1
        num_step += 1
    print("Epoch : {0} | num_balanced : {1}".format(l, num_balanced))

    # Generate Value Array
    true_value = np.append(
        (np.power(DISCOUNT,np.arange(num_balanced,0,-1)) - 1) / (DISCOUNT-1),
        np.zeros([STOP_CRT-num_balanced,1])
    )

    num_action0 = STOP_CRT - np.sum(action_history)
    num_action1 = np.sum(action_history)

    model0_state = np.zeros([STOP_CRT, 4])
    model1_state = np.zeros([STOP_CRT, 4])

    model0_value = np.zeros([STOP_CRT, 1])
    model1_value = np.zeros([STOP_CRT, 1])

    for i in np.arange(STOP_CRT):
        if action_history[i] == 0:
            model0_state[i, :] = state_history[i, :]
            model0_value[i, :] = true_value[i]
        else:
            model1_state[i, :] = state_history[i, :]
            model1_value[i, :] = true_value[i]

    # Learning
    if model0_value.shape[0] > 0 :
        model0.fit(model0_state[:num_action0,:], model0_value[:num_action0],initial_epoch=1)
    if model1_value.shape[0] > 0:
        model1.fit(model1_state[:num_action1,:], model1_value[:num_action1],initial_epoch=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Epoch : 0 | num_balanced : 8
# Epoch : 1 | num_balanced : 100
# Epoch : 2 | num_balanced : 12
# Epoch : 3 | num_balanced : 24
# Epoch : 4 | num_balanced : 25
# Epoch : 5 | num_balanced : 48
# Epoch : 6 | num_balanced : 13
# Epoch : 7 | num_balanced : 26
# Epoch : 8 | num_balanced : 24
# Epoch : 9 | num_balanced : 12
# Epoch : 10 | num_balanced : 16
# Epoch : 11 | num_balanced : 12
# Epoch : 12 | num_balanced : 94
# Epoch : 13 | num_balanced : 24
# Epoch : 14 | num_balanced : 16
# Epoch : 15 | num_balanced : 14
# Epoch : 16 | num_balanced : 17
# Epoch : 17 | num_balanced : 15
# Epoch : 18 | num_balanced : 16
# Epoch : 19 | num_balanced : 11
# Epoch : 20 | num_balanced : 14
# Epoch : 21 | num_balanced : 11
# Epoch : 22 | num_balanced : 31
# Epoch : 23 | num_balanced : 10
# Epoch : 24 | num_balanced : 16
# Epoch : 25 | num_balanced : 21
# Epoch : 26 | num_balanced : 17
# Epoch : 27 | num_balanced : 39
# Epoch : 28 | num_balanced : 19
# Epoch : 29 | num_balanced : 14
# Epoch : 30 | num_balanced : 20
# Epoch : 31 | num_balanced : 25
# Epoch : 32 | num_balanced : 20
# Epoch : 33 | num_balanced : 15
# Epoch : 34 | num_balanced : 29
# Epoch : 35 | num_balanced : 13
# Epoch : 36 | num_balanced : 27
# Epoch : 37 | num_balanced : 9
# Epoch : 38 | num_balanced : 12
# Epoch : 39 | num_balanced : 15
# Epoch : 40 | num_balanced : 29
# Epoch : 41 | num_balanced : 19
# Epoch : 42 | num_balanced : 11
# Epoch : 43 | num_balanced : 23
# Epoch : 44 | num_balanced : 11
# Epoch : 45 | num_balanced : 12
# Epoch : 46 | num_balanced : 14
# Epoch : 47 | num_balanced : 48
# Epoch : 48 | num_balanced : 16
# Epoch : 49 | num_balanced : 13
# Epoch : 50 | num_balanced : 30
# Epoch : 51 | num_balanced : 15
# Epoch : 52 | num_balanced : 12
# Epoch : 53 | num_balanced : 17
# Epoch : 54 | num_balanced : 13
# Epoch : 55 | num_balanced : 13
# Epoch : 56 | num_balanced : 18
# Epoch : 57 | num_balanced : 32
# Epoch : 58 | num_balanced : 24
# Epoch : 59 | num_balanced : 8
# Epoch : 60 | num_balanced : 26
# Epoch : 61 | num_balanced : 22
# Epoch : 62 | num_balanced : 36
# Epoch : 63 | num_balanced : 21
# Epoch : 64 | num_balanced : 25
# Epoch : 65 | num_balanced : 22
# Epoch : 66 | num_balanced : 13
# Epoch : 67 | num_balanced : 14
# Epoch : 68 | num_balanced : 52
# Epoch : 69 | num_balanced : 11
# Epoch : 70 | num_balanced : 59
# Epoch : 71 | num_balanced : 37
# Epoch : 72 | num_balanced : 31
# Epoch : 73 | num_balanced : 15
# Epoch : 74 | num_balanced : 16
# Epoch : 75 | num_balanced : 21
# Epoch : 76 | num_balanced : 25
# Epoch : 77 | num_balanced : 13
# Epoch : 78 | num_balanced : 21
# Epoch : 79 | num_balanced : 22
# Epoch : 80 | num_balanced : 29
# Epoch : 81 | num_balanced : 28
# Epoch : 82 | num_balanced : 15
# Epoch : 83 | num_balanced : 42
# Epoch : 84 | num_balanced : 15
# Epoch : 85 | num_balanced : 48
# Epoch : 86 | num_balanced : 44
# Epoch : 87 | num_balanced : 13
# Epoch : 88 | num_balanced : 9
# Epoch : 89 | num_balanced : 16
# Epoch : 90 | num_balanced : 25
# Epoch : 91 | num_balanced : 46
# Epoch : 92 | num_balanced : 10
# Epoch : 93 | num_balanced : 17
# Epoch : 94 | num_balanced : 30
# Epoch : 95 | num_balanced : 17
# Epoch : 96 | num_balanced : 18
# Epoch : 97 | num_balanced : 15
# Epoch : 98 | num_balanced : 22
# Epoch : 99 | num_balanced : 56

# %%
# Generate Environment
state = env.reset()
# For Every Learning Iterations
done = False
playtime = 0
while not done:
    state = state.reshape([-1, 4])
    values = np.array([model0(state)[0,0],model1(state)[0,0]])
    action =  np.argmax(values)
    state, reward, done, info = env.step(action)
    playtime += 1
print(playtime)
env.close()
# Out:
# 351

# %% [markdown]
# **New Version**

# %%
# Constants
STOP_CRT = 300
TEMP = 0.3
DISCOUNT = 0.99
EPOCH = 500
# Generate Environment
env = gym.make('CartPole-v1')

# For Every Learning Iterations
state_history = np.zeros((STOP_CRT, 4))
estimated_value_history = np.zeros((STOP_CRT, 2))
action_history = np.zeros((STOP_CRT, 1), dtype=int)
best = 0

for l in np.arange(EPOCH):
    state = env.reset().reshape([-1,4])
    num_step = 0
    num_action = np.zeros((2,),dtype=int)
    done = False
    #//// saving done=True states ?
    while (not done) and (num_step < STOP_CRT):
        values = np.array([model0(state)[0,0],model1(state)[0,0]])
        # Select Action
        # //// Maybe going greedy after some amount of step is advisable
        #action = np.random.randint(0,2)
        if np.random.random(1) < (np.exp(values[0] * TEMP) / (np.sum(np.exp(values * TEMP)))):
            action = int(0)
        else:
            action = int(1)
        num_action[action] += int(1)
        # Save Current Step
        state_history[num_step,:] = state
        estimated_value_history[num_step,:] = values
        action_history[num_step,0] = action
        # Do Action
        state, _, done, _ = env.step(action)
        state = state.reshape([-1, 4])
        num_step += 1
    print("Epoch : {0} | score : {1} | best : {2} | {3} vs {4}".format(l, num_step, best, num_action[0], num_action[1]))
    
    if best < num_step:
        best = num_step

    # Generate Value Array
    true_value = np.append((np.power(DISCOUNT,np.arange(num_step,0,-1)) - 1) / (DISCOUNT-1),0)

    model0_state = np.empty([0, 4])
    model1_state = np.empty([0, 4])

    model0_value = np.empty([0, 1])
    model1_value = np.empty([0, 1])

    for i in np.arange(num_step):
        if action_history[i] == 0:
            model0_state = np.vstack([model0_state, state_history[i, :]])
            model0_value = np.vstack([model0_value, true_value[i]])
        else:
            model1_state = np.vstack([model1_state, state_history[i, :]])
            model1_value = np.vstack([model1_value, true_value[i]])

    # Learning
    if model0_value.shape[0] > 0 :
        model0.fit(model0_state[-1 * np.min([10,num_action[0]]):], model0_value[-1 * np.min([10,num_action[0]]):])
    if model1_value.shape[0] > 0:
        model1.fit(model1_state[-1 * np.min([10,num_action[1]]):], model1_value[-1 * np.min([10,num_action[1]]):])
# Out:
# Epoch : 0 | score : 12 | best : 0 | 10 vs 2
# 1/1 [==============================] - 0s 4ms/step - loss: 278.6388 - mean_squared_error: 278.6388
# 1/1 [==============================] - 0s 3ms/step - loss: 159.6801 - mean_squared_error: 159.6801
# Epoch : 1 | score : 11 | best : 12 | 9 vs 2
# 1/1 [==============================] - 0s 3ms/step - loss: 70.0585 - mean_squared_error: 70.0585
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9590 - mean_squared_error: 1.9590
# Epoch : 2 | score : 10 | best : 12 | 7 vs 3
# 1/1 [==============================] - 0s 3ms/step - loss: 76.4202 - mean_squared_error: 76.4202
# 1/1 [==============================] - 0s 3ms/step - loss: 23.4067 - mean_squared_error: 23.4067
# Epoch : 3 | score : 89 | best : 12 | 48 vs 41
# 1/1 [==============================] - 0s 4ms/step - loss: 219.2492 - mean_squared_error: 219.2492
# 1/1 [==============================] - 0s 4ms/step - loss: 87.2499 - mean_squared_error: 87.2499
# Epoch : 4 | score : 91 | best : 89 | 51 vs 40
# 1/1 [==============================] - 0s 4ms/step - loss: 70.0193 - mean_squared_error: 70.0193
# 1/1 [==============================] - 0s 4ms/step - loss: 31.6076 - mean_squared_error: 31.6076
# Epoch : 5 | score : 48 | best : 91 | 25 vs 23
# 1/1 [==============================] - 0s 4ms/step - loss: 53.9800 - mean_squared_error: 53.9800
# 1/1 [==============================] - 0s 4ms/step - loss: 33.2223 - mean_squared_error: 33.2223
# Epoch : 6 | score : 90 | best : 91 | 51 vs 39
# 1/1 [==============================] - 0s 4ms/step - loss: 26.0287 - mean_squared_error: 26.0287
# 1/1 [==============================] - 0s 4ms/step - loss: 18.2870 - mean_squared_error: 18.2870
# Epoch : 7 | score : 107 | best : 91 | 59 vs 48
# 1/1 [==============================] - 0s 4ms/step - loss: 25.9946 - mean_squared_error: 25.9946
# 1/1 [==============================] - 0s 4ms/step - loss: 23.5444 - mean_squared_error: 23.5444
# Epoch : 8 | score : 84 | best : 107 | 47 vs 37
# 1/1 [==============================] - 0s 3ms/step - loss: 32.2334 - mean_squared_error: 32.2334
# 1/1 [==============================] - 0s 3ms/step - loss: 11.1199 - mean_squared_error: 11.1199
# Epoch : 9 | score : 48 | best : 107 | 28 vs 20
# 1/1 [==============================] - 0s 4ms/step - loss: 46.3611 - mean_squared_error: 46.3611
# 1/1 [==============================] - 0s 6ms/step - loss: 21.3483 - mean_squared_error: 21.3483
# Epoch : 10 | score : 47 | best : 107 | 25 vs 22
# 1/1 [==============================] - 0s 5ms/step - loss: 48.0781 - mean_squared_error: 48.0781
# 1/1 [==============================] - 0s 4ms/step - loss: 40.0199 - mean_squared_error: 40.0199
# Epoch : 11 | score : 14 | best : 107 | 5 vs 9
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3253 - mean_squared_error: 3.3253
# 1/1 [==============================] - 0s 4ms/step - loss: 37.6927 - mean_squared_error: 37.6927
# Epoch : 12 | score : 16 | best : 107 | 5 vs 11
# 1/1 [==============================] - 0s 4ms/step - loss: 8.1467 - mean_squared_error: 8.1467
# 1/1 [==============================] - 0s 4ms/step - loss: 34.4061 - mean_squared_error: 34.4061
# Epoch : 13 | score : 12 | best : 107 | 4 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1686 - mean_squared_error: 2.1686
# 1/1 [==============================] - 0s 4ms/step - loss: 17.6578 - mean_squared_error: 17.6578
# Epoch : 14 | score : 97 | best : 107 | 53 vs 44
# 1/1 [==============================] - 0s 3ms/step - loss: 47.5850 - mean_squared_error: 47.5850
# 1/1 [==============================] - 0s 3ms/step - loss: 13.0484 - mean_squared_error: 13.0484
# Epoch : 15 | score : 21 | best : 107 | 9 vs 12
# 1/1 [==============================] - 0s 3ms/step - loss: 10.5020 - mean_squared_error: 10.5020
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9894 - mean_squared_error: 4.9894
# Epoch : 16 | score : 82 | best : 107 | 45 vs 37
# 1/1 [==============================] - 0s 6ms/step - loss: 21.9663 - mean_squared_error: 21.9663
# 1/1 [==============================] - 0s 3ms/step - loss: 22.0223 - mean_squared_error: 22.0223
# Epoch : 17 | score : 39 | best : 107 | 22 vs 17
# 1/1 [==============================] - 0s 3ms/step - loss: 30.5620 - mean_squared_error: 30.5620
# 1/1 [==============================] - 0s 3ms/step - loss: 23.3290 - mean_squared_error: 23.3290
# Epoch : 18 | score : 31 | best : 107 | 15 vs 16
# 1/1 [==============================] - 0s 4ms/step - loss: 18.7336 - mean_squared_error: 18.7336
# 1/1 [==============================] - 0s 3ms/step - loss: 14.3001 - mean_squared_error: 14.3001
# Epoch : 19 | score : 10 | best : 107 | 2 vs 8
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1949 - mean_squared_error: 4.1949
# 1/1 [==============================] - 0s 3ms/step - loss: 23.4803 - mean_squared_error: 23.4803
# Epoch : 20 | score : 21 | best : 107 | 10 vs 11
# 1/1 [==============================] - 0s 4ms/step - loss: 23.7791 - mean_squared_error: 23.7791
# 1/1 [==============================] - 0s 4ms/step - loss: 16.2859 - mean_squared_error: 16.2859
# Epoch : 21 | score : 11 | best : 107 | 4 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3296 - mean_squared_error: 3.3296
# 1/1 [==============================] - 0s 4ms/step - loss: 10.8298 - mean_squared_error: 10.8298
# Epoch : 22 | score : 65 | best : 107 | 34 vs 31
# 1/1 [==============================] - 0s 3ms/step - loss: 24.4605 - mean_squared_error: 24.4605
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4592 - mean_squared_error: 5.4592
# Epoch : 23 | score : 89 | best : 107 | 50 vs 39
# 1/1 [==============================] - 0s 3ms/step - loss: 25.0098 - mean_squared_error: 25.0098
# 1/1 [==============================] - 0s 3ms/step - loss: 52.8108 - mean_squared_error: 52.8108
# Epoch : 24 | score : 32 | best : 107 | 15 vs 17
# 1/1 [==============================] - 0s 4ms/step - loss: 13.9360 - mean_squared_error: 13.9360
# 1/1 [==============================] - 0s 3ms/step - loss: 16.6121 - mean_squared_error: 16.6121
# Epoch : 25 | score : 12 | best : 107 | 3 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9133 - mean_squared_error: 1.9133
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9252 - mean_squared_error: 9.9252
# Epoch : 26 | score : 18 | best : 107 | 8 vs 10
# 1/1 [==============================] - 0s 5ms/step - loss: 4.2316 - mean_squared_error: 4.2316
# 1/1 [==============================] - 0s 4ms/step - loss: 11.0785 - mean_squared_error: 11.0785
# Epoch : 27 | score : 28 | best : 107 | 14 vs 14
# 1/1 [==============================] - 0s 4ms/step - loss: 21.7448 - mean_squared_error: 21.7448
# 1/1 [==============================] - 0s 4ms/step - loss: 23.5615 - mean_squared_error: 23.5615
# Epoch : 28 | score : 126 | best : 107 | 70 vs 56
# 1/1 [==============================] - 0s 3ms/step - loss: 24.8555 - mean_squared_error: 24.8555
# 1/1 [==============================] - 0s 4ms/step - loss: 28.9619 - mean_squared_error: 28.9619
# Epoch : 29 | score : 17 | best : 126 | 10 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 15.0296 - mean_squared_error: 15.0296
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8254 - mean_squared_error: 9.8254
# Epoch : 30 | score : 12 | best : 126 | 8 vs 4
# 1/1 [==============================] - 0s 4ms/step - loss: 10.7924 - mean_squared_error: 10.7924
# 1/1 [==============================] - 0s 4ms/step - loss: 13.7595 - mean_squared_error: 13.7595
# Epoch : 31 | score : 84 | best : 126 | 46 vs 38
# 1/1 [==============================] - 0s 4ms/step - loss: 14.3300 - mean_squared_error: 14.3300
# 1/1 [==============================] - 0s 4ms/step - loss: 16.2836 - mean_squared_error: 16.2836
# Epoch : 32 | score : 25 | best : 126 | 14 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 29.4153 - mean_squared_error: 29.4153
# 1/1 [==============================] - 0s 3ms/step - loss: 63.0298 - mean_squared_error: 63.0298
# Epoch : 33 | score : 16 | best : 126 | 6 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9828 - mean_squared_error: 2.9828
# 1/1 [==============================] - 0s 3ms/step - loss: 10.1496 - mean_squared_error: 10.1496
# Epoch : 34 | score : 30 | best : 126 | 16 vs 14
# 1/1 [==============================] - 0s 3ms/step - loss: 26.2679 - mean_squared_error: 26.2679
# 1/1 [==============================] - 0s 4ms/step - loss: 47.3512 - mean_squared_error: 47.3512
# Epoch : 35 | score : 18 | best : 126 | 6 vs 12
# 1/1 [==============================] - 0s 3ms/step - loss: 7.9178 - mean_squared_error: 7.9178
# 1/1 [==============================] - 0s 5ms/step - loss: 6.6380 - mean_squared_error: 6.6380
# Epoch : 36 | score : 31 | best : 126 | 16 vs 15
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6317 - mean_squared_error: 9.6317
# 1/1 [==============================] - 0s 3ms/step - loss: 13.0995 - mean_squared_error: 13.0995
# Epoch : 37 | score : 26 | best : 126 | 12 vs 14
# 1/1 [==============================] - 0s 3ms/step - loss: 45.7836 - mean_squared_error: 45.7836
# 1/1 [==============================] - 0s 4ms/step - loss: 20.1733 - mean_squared_error: 20.1733
# Epoch : 38 | score : 45 | best : 126 | 23 vs 22
# 1/1 [==============================] - 0s 5ms/step - loss: 15.1063 - mean_squared_error: 15.1063
# 1/1 [==============================] - 0s 3ms/step - loss: 13.1941 - mean_squared_error: 13.1941
# Epoch : 39 | score : 24 | best : 126 | 12 vs 12
# 1/1 [==============================] - 0s 3ms/step - loss: 29.0364 - mean_squared_error: 29.0364
# 1/1 [==============================] - 0s 3ms/step - loss: 13.0901 - mean_squared_error: 13.0901
# Epoch : 40 | score : 18 | best : 126 | 7 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 11.7707 - mean_squared_error: 11.7707
# 1/1 [==============================] - 0s 4ms/step - loss: 8.0980 - mean_squared_error: 8.0980
# Epoch : 41 | score : 24 | best : 126 | 11 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 19.4362 - mean_squared_error: 19.4362
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4172 - mean_squared_error: 9.4172
# Epoch : 42 | score : 43 | best : 126 | 24 vs 19
# 1/1 [==============================] - 0s 4ms/step - loss: 16.9133 - mean_squared_error: 16.9133
# 1/1 [==============================] - 0s 3ms/step - loss: 14.8507 - mean_squared_error: 14.8507
# Epoch : 43 | score : 26 | best : 126 | 13 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1419 - mean_squared_error: 6.1419
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6888 - mean_squared_error: 4.6888
# Epoch : 44 | score : 23 | best : 126 | 10 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 26.1932 - mean_squared_error: 26.1932
# 1/1 [==============================] - 0s 4ms/step - loss: 12.1995 - mean_squared_error: 12.1995
# Epoch : 45 | score : 51 | best : 126 | 26 vs 25
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2824 - mean_squared_error: 6.2824
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3723 - mean_squared_error: 6.3723
# Epoch : 46 | score : 152 | best : 126 | 81 vs 71
# 1/1 [==============================] - 0s 4ms/step - loss: 21.0670 - mean_squared_error: 21.0670
# 1/1 [==============================] - 0s 3ms/step - loss: 27.3356 - mean_squared_error: 27.3356
# Epoch : 47 | score : 91 | best : 152 | 50 vs 41
# 1/1 [==============================] - 0s 3ms/step - loss: 18.0112 - mean_squared_error: 18.0112
# 1/1 [==============================] - 0s 3ms/step - loss: 55.8360 - mean_squared_error: 55.8360
# Epoch : 48 | score : 37 | best : 152 | 20 vs 17
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4000 - mean_squared_error: 3.4000
# 1/1 [==============================] - 0s 4ms/step - loss: 16.0938 - mean_squared_error: 16.0938
# Epoch : 49 | score : 27 | best : 152 | 11 vs 16
# 1/1 [==============================] - 0s 4ms/step - loss: 22.2600 - mean_squared_error: 22.2600
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8997 - mean_squared_error: 9.8997
# Epoch : 50 | score : 90 | best : 152 | 49 vs 41
# 1/1 [==============================] - 0s 4ms/step - loss: 26.0856 - mean_squared_error: 26.0856
# 1/1 [==============================] - 0s 4ms/step - loss: 22.1822 - mean_squared_error: 22.1822
# Epoch : 51 | score : 130 | best : 152 | 65 vs 65
# 1/1 [==============================] - 0s 3ms/step - loss: 16.0968 - mean_squared_error: 16.0968
# 1/1 [==============================] - 0s 4ms/step - loss: 9.8874 - mean_squared_error: 9.8874
# Epoch : 52 | score : 105 | best : 152 | 54 vs 51
# 1/1 [==============================] - 0s 3ms/step - loss: 11.4880 - mean_squared_error: 11.4880
# 1/1 [==============================] - 0s 4ms/step - loss: 15.6969 - mean_squared_error: 15.6969
# Epoch : 53 | score : 59 | best : 152 | 28 vs 31
# 1/1 [==============================] - 0s 3ms/step - loss: 12.4499 - mean_squared_error: 12.4499
# 1/1 [==============================] - 0s 3ms/step - loss: 8.1089 - mean_squared_error: 8.1089
# Epoch : 54 | score : 22 | best : 152 | 12 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 40.0837 - mean_squared_error: 40.0837
# 1/1 [==============================] - 0s 4ms/step - loss: 19.5112 - mean_squared_error: 19.5112
# Epoch : 55 | score : 96 | best : 152 | 53 vs 43
# 1/1 [==============================] - 0s 3ms/step - loss: 18.1441 - mean_squared_error: 18.1441
# 1/1 [==============================] - 0s 3ms/step - loss: 34.4471 - mean_squared_error: 34.4471
# Epoch : 56 | score : 29 | best : 152 | 16 vs 13
# 1/1 [==============================] - 0s 4ms/step - loss: 21.0355 - mean_squared_error: 21.0355
# 1/1 [==============================] - 0s 3ms/step - loss: 24.9886 - mean_squared_error: 24.9886
# Epoch : 57 | score : 25 | best : 152 | 8 vs 17
# 1/1 [==============================] - 0s 3ms/step - loss: 57.0201 - mean_squared_error: 57.0201
# 1/1 [==============================] - 0s 3ms/step - loss: 10.2588 - mean_squared_error: 10.2588
# Epoch : 58 | score : 18 | best : 152 | 11 vs 7
# 1/1 [==============================] - 0s 3ms/step - loss: 5.8495 - mean_squared_error: 5.8495
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3940 - mean_squared_error: 3.3940
# Epoch : 59 | score : 18 | best : 152 | 8 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7984 - mean_squared_error: 7.7984
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0014 - mean_squared_error: 6.0014
# Epoch : 60 | score : 76 | best : 152 | 40 vs 36
# 1/1 [==============================] - 0s 3ms/step - loss: 26.6784 - mean_squared_error: 26.6784
# 1/1 [==============================] - 0s 3ms/step - loss: 11.3169 - mean_squared_error: 11.3169
# Epoch : 61 | score : 37 | best : 152 | 18 vs 19
# 1/1 [==============================] - 0s 5ms/step - loss: 13.9445 - mean_squared_error: 13.9445
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3001 - mean_squared_error: 9.3001
# Epoch : 62 | score : 42 | best : 152 | 19 vs 23
# 1/1 [==============================] - 0s 3ms/step - loss: 21.3077 - mean_squared_error: 21.3077
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4222 - mean_squared_error: 4.4222
# Epoch : 63 | score : 16 | best : 152 | 9 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0099 - mean_squared_error: 6.0099
# 1/1 [==============================] - 0s 4ms/step - loss: 9.3908 - mean_squared_error: 9.3908
# Epoch : 64 | score : 11 | best : 152 | 8 vs 3
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9278 - mean_squared_error: 4.9278
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9966 - mean_squared_error: 5.9966
# Epoch : 65 | score : 60 | best : 152 | 31 vs 29
# 1/1 [==============================] - 0s 3ms/step - loss: 11.9494 - mean_squared_error: 11.9494
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7623 - mean_squared_error: 4.7623
# Epoch : 66 | score : 72 | best : 152 | 38 vs 34
# 1/1 [==============================] - 0s 3ms/step - loss: 11.0848 - mean_squared_error: 11.0848
# 1/1 [==============================] - 0s 3ms/step - loss: 9.5940 - mean_squared_error: 9.5940
# Epoch : 67 | score : 119 | best : 152 | 63 vs 56
# 1/1 [==============================] - 0s 3ms/step - loss: 22.7749 - mean_squared_error: 22.7749
# 1/1 [==============================] - 0s 3ms/step - loss: 27.1304 - mean_squared_error: 27.1304
# Epoch : 68 | score : 27 | best : 152 | 14 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3952 - mean_squared_error: 9.3952
# 1/1 [==============================] - 0s 3ms/step - loss: 10.9511 - mean_squared_error: 10.9511
# Epoch : 69 | score : 117 | best : 152 | 63 vs 54
# 1/1 [==============================] - 0s 4ms/step - loss: 25.0775 - mean_squared_error: 25.0775
# 1/1 [==============================] - 0s 4ms/step - loss: 37.7452 - mean_squared_error: 37.7452
# Epoch : 70 | score : 90 | best : 152 | 47 vs 43
# 1/1 [==============================] - 0s 4ms/step - loss: 16.7263 - mean_squared_error: 16.7263
# 1/1 [==============================] - 0s 3ms/step - loss: 10.4115 - mean_squared_error: 10.4115
# Epoch : 71 | score : 13 | best : 152 | 4 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 11.4678 - mean_squared_error: 11.4678
# 1/1 [==============================] - 0s 3ms/step - loss: 17.2520 - mean_squared_error: 17.2520
# Epoch : 72 | score : 26 | best : 152 | 10 vs 16
# 1/1 [==============================] - 0s 3ms/step - loss: 17.7354 - mean_squared_error: 17.7354
# 1/1 [==============================] - 0s 4ms/step - loss: 10.8692 - mean_squared_error: 10.8692
# Epoch : 73 | score : 36 | best : 152 | 17 vs 19
# 1/1 [==============================] - 0s 4ms/step - loss: 13.2211 - mean_squared_error: 13.2211
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9637 - mean_squared_error: 3.9637
# Epoch : 74 | score : 86 | best : 152 | 42 vs 44
# 1/1 [==============================] - 0s 4ms/step - loss: 12.8722 - mean_squared_error: 12.8722
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8741 - mean_squared_error: 3.8741
# Epoch : 75 | score : 26 | best : 152 | 14 vs 12
# 1/1 [==============================] - 0s 3ms/step - loss: 11.6612 - mean_squared_error: 11.6612
# 1/1 [==============================] - 0s 4ms/step - loss: 13.5622 - mean_squared_error: 13.5622
# Epoch : 76 | score : 20 | best : 152 | 7 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9614 - mean_squared_error: 3.9614
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8760 - mean_squared_error: 6.8760
# Epoch : 77 | score : 135 | best : 152 | 69 vs 66
# 1/1 [==============================] - 0s 3ms/step - loss: 49.1421 - mean_squared_error: 49.1421
# 1/1 [==============================] - 0s 3ms/step - loss: 10.2788 - mean_squared_error: 10.2788
# Epoch : 78 | score : 14 | best : 152 | 8 vs 6
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2971 - mean_squared_error: 4.2971
# 1/1 [==============================] - 0s 3ms/step - loss: 8.2811 - mean_squared_error: 8.2811
# Epoch : 79 | score : 184 | best : 152 | 98 vs 86
# 1/1 [==============================] - 0s 4ms/step - loss: 24.9544 - mean_squared_error: 24.9544
# 1/1 [==============================] - 0s 5ms/step - loss: 29.3702 - mean_squared_error: 29.3702
# Epoch : 80 | score : 19 | best : 184 | 10 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 10.6654 - mean_squared_error: 10.6654
# 1/1 [==============================] - 0s 3ms/step - loss: 8.7350 - mean_squared_error: 8.7350
# Epoch : 81 | score : 17 | best : 184 | 11 vs 6
# 1/1 [==============================] - 0s 4ms/step - loss: 10.4838 - mean_squared_error: 10.4838
# 1/1 [==============================] - 0s 4ms/step - loss: 8.5983 - mean_squared_error: 8.5983
# Epoch : 82 | score : 158 | best : 184 | 84 vs 74
# 1/1 [==============================] - 0s 3ms/step - loss: 21.2084 - mean_squared_error: 21.2084
# 1/1 [==============================] - 0s 3ms/step - loss: 30.4013 - mean_squared_error: 30.4013
# Epoch : 83 | score : 158 | best : 184 | 81 vs 77
# 1/1 [==============================] - 0s 4ms/step - loss: 33.1587 - mean_squared_error: 33.1587
# 1/1 [==============================] - 0s 4ms/step - loss: 13.3690 - mean_squared_error: 13.3690
# Epoch : 84 | score : 20 | best : 184 | 11 vs 9
# 1/1 [==============================] - 0s 6ms/step - loss: 10.5939 - mean_squared_error: 10.5939
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2228 - mean_squared_error: 7.2228
# Epoch : 85 | score : 147 | best : 184 | 76 vs 71
# 1/1 [==============================] - 0s 3ms/step - loss: 18.0140 - mean_squared_error: 18.0140
# 1/1 [==============================] - 0s 3ms/step - loss: 16.8671 - mean_squared_error: 16.8671
# Epoch : 86 | score : 19 | best : 184 | 11 vs 8
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6007 - mean_squared_error: 2.6007
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5554 - mean_squared_error: 2.5554
# Epoch : 87 | score : 73 | best : 184 | 38 vs 35
# 1/1 [==============================] - 0s 3ms/step - loss: 27.7709 - mean_squared_error: 27.7709
# 1/1 [==============================] - 0s 3ms/step - loss: 12.5391 - mean_squared_error: 12.5391
# Epoch : 88 | score : 159 | best : 184 | 86 vs 73
# 1/1 [==============================] - 0s 3ms/step - loss: 18.9648 - mean_squared_error: 18.9648
# 1/1 [==============================] - 0s 4ms/step - loss: 70.2328 - mean_squared_error: 70.2328
# Epoch : 89 | score : 14 | best : 184 | 4 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 10.8004 - mean_squared_error: 10.8004
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2822 - mean_squared_error: 9.2822
# Epoch : 90 | score : 13 | best : 184 | 3 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7306 - mean_squared_error: 5.7306
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6956 - mean_squared_error: 4.6956
# Epoch : 91 | score : 40 | best : 184 | 19 vs 21
# 1/1 [==============================] - 0s 7ms/step - loss: 23.0921 - mean_squared_error: 23.0921
# 1/1 [==============================] - 0s 4ms/step - loss: 16.1361 - mean_squared_error: 16.1361
# Epoch : 92 | score : 22 | best : 184 | 12 vs 10
# 1/1 [==============================] - 0s 6ms/step - loss: 45.5703 - mean_squared_error: 45.5703
# 1/1 [==============================] - 0s 4ms/step - loss: 13.7064 - mean_squared_error: 13.7064
# Epoch : 93 | score : 124 | best : 184 | 66 vs 58
# 1/1 [==============================] - 0s 3ms/step - loss: 25.8417 - mean_squared_error: 25.8417
# 1/1 [==============================] - 0s 4ms/step - loss: 10.3153 - mean_squared_error: 10.3153
# Epoch : 94 | score : 19 | best : 184 | 8 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4058 - mean_squared_error: 7.4058
# 1/1 [==============================] - 0s 3ms/step - loss: 11.0170 - mean_squared_error: 11.0170
# Epoch : 95 | score : 91 | best : 184 | 47 vs 44
# 1/1 [==============================] - 0s 3ms/step - loss: 22.4310 - mean_squared_error: 22.4310
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3785 - mean_squared_error: 4.3785
# Epoch : 96 | score : 108 | best : 184 | 51 vs 57
# 1/1 [==============================] - 0s 3ms/step - loss: 33.5999 - mean_squared_error: 33.5999
# 1/1 [==============================] - 0s 4ms/step - loss: 5.2443 - mean_squared_error: 5.2443
# Epoch : 97 | score : 85 | best : 184 | 44 vs 41
# 1/1 [==============================] - 0s 3ms/step - loss: 22.0802 - mean_squared_error: 22.0802
# 1/1 [==============================] - 0s 3ms/step - loss: 43.4695 - mean_squared_error: 43.4695
# Epoch : 98 | score : 32 | best : 184 | 18 vs 14
# 1/1 [==============================] - 0s 4ms/step - loss: 5.1130 - mean_squared_error: 5.1130
# 1/1 [==============================] - 0s 5ms/step - loss: 11.2853 - mean_squared_error: 11.2853
# Epoch : 99 | score : 41 | best : 184 | 22 vs 19
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2827 - mean_squared_error: 4.2827
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4504 - mean_squared_error: 5.4504
# Epoch : 100 | score : 112 | best : 184 | 58 vs 54
# 1/1 [==============================] - 0s 4ms/step - loss: 26.6129 - mean_squared_error: 26.6129
# 1/1 [==============================] - 0s 3ms/step - loss: 16.4843 - mean_squared_error: 16.4843
# Epoch : 101 | score : 26 | best : 184 | 11 vs 15
# 1/1 [==============================] - 0s 3ms/step - loss: 11.4020 - mean_squared_error: 11.4020
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4353 - mean_squared_error: 1.4353
# Epoch : 102 | score : 160 | best : 184 | 78 vs 82
# 1/1 [==============================] - 0s 4ms/step - loss: 17.3687 - mean_squared_error: 17.3687
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6163 - mean_squared_error: 7.6163
# Epoch : 103 | score : 80 | best : 184 | 40 vs 40
# 1/1 [==============================] - 0s 4ms/step - loss: 36.9286 - mean_squared_error: 36.9286
# 1/1 [==============================] - 0s 4ms/step - loss: 30.5121 - mean_squared_error: 30.5121
# Epoch : 104 | score : 110 | best : 184 | 58 vs 52
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9670 - mean_squared_error: 5.9670
# 1/1 [==============================] - 0s 4ms/step - loss: 36.7135 - mean_squared_error: 36.7135
# Epoch : 105 | score : 118 | best : 184 | 61 vs 57
# 1/1 [==============================] - 0s 4ms/step - loss: 16.6532 - mean_squared_error: 16.6532
# 1/1 [==============================] - 0s 4ms/step - loss: 21.9194 - mean_squared_error: 21.9194
# Epoch : 106 | score : 141 | best : 184 | 71 vs 70
# 1/1 [==============================] - 0s 4ms/step - loss: 15.2128 - mean_squared_error: 15.2128
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2961 - mean_squared_error: 5.2961
# Epoch : 107 | score : 161 | best : 184 | 86 vs 75
# 1/1 [==============================] - 0s 3ms/step - loss: 17.4521 - mean_squared_error: 17.4521
# 1/1 [==============================] - 0s 4ms/step - loss: 24.8803 - mean_squared_error: 24.8803
# Epoch : 108 | score : 101 | best : 184 | 49 vs 52
# 1/1 [==============================] - 0s 4ms/step - loss: 7.5180 - mean_squared_error: 7.5180
# 1/1 [==============================] - 0s 3ms/step - loss: 15.1249 - mean_squared_error: 15.1249
# Epoch : 109 | score : 153 | best : 184 | 82 vs 71
# 1/1 [==============================] - 0s 3ms/step - loss: 18.9013 - mean_squared_error: 18.9013
# 1/1 [==============================] - 0s 3ms/step - loss: 12.8273 - mean_squared_error: 12.8273
# Epoch : 110 | score : 14 | best : 184 | 8 vs 6
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8103 - mean_squared_error: 3.8103
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5481 - mean_squared_error: 1.5481
# Epoch : 111 | score : 52 | best : 184 | 27 vs 25
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9688 - mean_squared_error: 5.9688
# 1/1 [==============================] - 0s 3ms/step - loss: 11.6127 - mean_squared_error: 11.6127
# Epoch : 112 | score : 113 | best : 184 | 56 vs 57
# 1/1 [==============================] - 0s 4ms/step - loss: 11.8056 - mean_squared_error: 11.8056
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4106 - mean_squared_error: 2.4106
# Epoch : 113 | score : 42 | best : 184 | 27 vs 15
# 1/1 [==============================] - 0s 4ms/step - loss: 7.0139 - mean_squared_error: 7.0139
# 1/1 [==============================] - 0s 3ms/step - loss: 88.7634 - mean_squared_error: 88.7634
# Epoch : 114 | score : 11 | best : 184 | 3 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4465 - mean_squared_error: 2.4465
# 1/1 [==============================] - 0s 3ms/step - loss: 6.9357 - mean_squared_error: 6.9357
# Epoch : 115 | score : 29 | best : 184 | 10 vs 19
# 1/1 [==============================] - 0s 5ms/step - loss: 27.9066 - mean_squared_error: 27.9066
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7716 - mean_squared_error: 6.7716
# Epoch : 116 | score : 11 | best : 184 | 7 vs 4
# 1/1 [==============================] - 0s 3ms/step - loss: 5.5894 - mean_squared_error: 5.5894
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7888 - mean_squared_error: 2.7888
# Epoch : 117 | score : 18 | best : 184 | 11 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6106 - mean_squared_error: 5.6106
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5452 - mean_squared_error: 4.5452
# Epoch : 118 | score : 35 | best : 184 | 18 vs 17
# 1/1 [==============================] - 0s 4ms/step - loss: 16.1713 - mean_squared_error: 16.1713
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3824 - mean_squared_error: 9.3824
# Epoch : 119 | score : 91 | best : 184 | 45 vs 46
# 1/1 [==============================] - 0s 3ms/step - loss: 34.3506 - mean_squared_error: 34.3506
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4268 - mean_squared_error: 2.4268
# Epoch : 120 | score : 37 | best : 184 | 19 vs 18
# 1/1 [==============================] - 0s 4ms/step - loss: 22.1999 - mean_squared_error: 22.1999
# 1/1 [==============================] - 0s 3ms/step - loss: 13.7171 - mean_squared_error: 13.7171
# Epoch : 121 | score : 37 | best : 184 | 17 vs 20
# 1/1 [==============================] - 0s 4ms/step - loss: 7.6345 - mean_squared_error: 7.6345
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7643 - mean_squared_error: 8.7643
# Epoch : 122 | score : 46 | best : 184 | 21 vs 25
# 1/1 [==============================] - 0s 7ms/step - loss: 6.6932 - mean_squared_error: 6.6932
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2715 - mean_squared_error: 4.2715
# Epoch : 123 | score : 80 | best : 184 | 41 vs 39
# 1/1 [==============================] - 0s 4ms/step - loss: 11.7675 - mean_squared_error: 11.7675
# 1/1 [==============================] - 0s 3ms/step - loss: 8.2647 - mean_squared_error: 8.2647
# Epoch : 124 | score : 19 | best : 184 | 11 vs 8
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5709 - mean_squared_error: 2.5709
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0957 - mean_squared_error: 2.0957
# Epoch : 125 | score : 16 | best : 184 | 6 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0114 - mean_squared_error: 3.0114
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4969 - mean_squared_error: 5.4969
# Epoch : 126 | score : 75 | best : 184 | 41 vs 34
# 1/1 [==============================] - 0s 3ms/step - loss: 12.8568 - mean_squared_error: 12.8568
# 1/1 [==============================] - 0s 3ms/step - loss: 15.1761 - mean_squared_error: 15.1761
# Epoch : 127 | score : 93 | best : 184 | 46 vs 47
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2303 - mean_squared_error: 9.2303
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8485 - mean_squared_error: 6.8485
# Epoch : 128 | score : 75 | best : 184 | 33 vs 42
# 1/1 [==============================] - 0s 4ms/step - loss: 120.2347 - mean_squared_error: 120.2347
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8014 - mean_squared_error: 3.8014
# Epoch : 129 | score : 30 | best : 184 | 16 vs 14
# 1/1 [==============================] - 0s 3ms/step - loss: 18.0456 - mean_squared_error: 18.0456
# 1/1 [==============================] - 0s 4ms/step - loss: 17.1051 - mean_squared_error: 17.1051
# Epoch : 130 | score : 49 | best : 184 | 26 vs 23
# 1/1 [==============================] - 0s 3ms/step - loss: 25.5064 - mean_squared_error: 25.5064
# 1/1 [==============================] - 0s 3ms/step - loss: 15.4562 - mean_squared_error: 15.4562
# Epoch : 131 | score : 15 | best : 184 | 10 vs 5
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0495 - mean_squared_error: 4.0495
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1352 - mean_squared_error: 4.1352
# Epoch : 132 | score : 29 | best : 184 | 16 vs 13
# 1/1 [==============================] - 0s 4ms/step - loss: 10.1559 - mean_squared_error: 10.1559
# 1/1 [==============================] - 0s 5ms/step - loss: 21.7579 - mean_squared_error: 21.7579
# Epoch : 133 | score : 18 | best : 184 | 12 vs 6
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0385 - mean_squared_error: 3.0385
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9956 - mean_squared_error: 3.9956
# Epoch : 134 | score : 14 | best : 184 | 4 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9208 - mean_squared_error: 2.9208
# 1/1 [==============================] - 0s 3ms/step - loss: 6.5643 - mean_squared_error: 6.5643
# Epoch : 135 | score : 138 | best : 184 | 70 vs 68
# 1/1 [==============================] - 0s 3ms/step - loss: 14.1528 - mean_squared_error: 14.1528
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7065 - mean_squared_error: 6.7065
# Epoch : 136 | score : 44 | best : 184 | 20 vs 24
# 1/1 [==============================] - 0s 3ms/step - loss: 19.2412 - mean_squared_error: 19.2412
# 1/1 [==============================] - 0s 3ms/step - loss: 6.5489 - mean_squared_error: 6.5489
# Epoch : 137 | score : 19 | best : 184 | 7 vs 12
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5991 - mean_squared_error: 1.5991
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7104 - mean_squared_error: 2.7104
# Epoch : 138 | score : 25 | best : 184 | 16 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9773 - mean_squared_error: 2.9773
# 1/1 [==============================] - 0s 3ms/step - loss: 14.0140 - mean_squared_error: 14.0140
# Epoch : 139 | score : 34 | best : 184 | 20 vs 14
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1442 - mean_squared_error: 2.1442
# 1/1 [==============================] - 0s 3ms/step - loss: 31.8650 - mean_squared_error: 31.8650
# Epoch : 140 | score : 30 | best : 184 | 18 vs 12
# 1/1 [==============================] - 0s 4ms/step - loss: 3.3408 - mean_squared_error: 3.3408
# 1/1 [==============================] - 0s 3ms/step - loss: 25.2215 - mean_squared_error: 25.2215
# Epoch : 141 | score : 16 | best : 184 | 5 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8921 - mean_squared_error: 1.8921
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9328 - mean_squared_error: 9.9328
# Epoch : 142 | score : 94 | best : 184 | 47 vs 47
# 1/1 [==============================] - 0s 4ms/step - loss: 27.7943 - mean_squared_error: 27.7943
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8614 - mean_squared_error: 4.8614
# Epoch : 143 | score : 79 | best : 184 | 40 vs 39
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8315 - mean_squared_error: 5.8315
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2632 - mean_squared_error: 2.2632
# Epoch : 144 | score : 111 | best : 184 | 59 vs 52
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2089 - mean_squared_error: 6.2089
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3696 - mean_squared_error: 8.3696
# Epoch : 145 | score : 26 | best : 184 | 10 vs 16
# 1/1 [==============================] - 0s 4ms/step - loss: 15.7922 - mean_squared_error: 15.7922
# 1/1 [==============================] - 0s 5ms/step - loss: 10.3922 - mean_squared_error: 10.3922
# Epoch : 146 | score : 10 | best : 184 | 7 vs 3
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6162 - mean_squared_error: 4.6162
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4667 - mean_squared_error: 1.4667
# Epoch : 147 | score : 109 | best : 184 | 54 vs 55
# 1/1 [==============================] - 0s 4ms/step - loss: 8.8970 - mean_squared_error: 8.8970
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5203 - mean_squared_error: 3.5203
# Epoch : 148 | score : 13 | best : 184 | 6 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 12.5412 - mean_squared_error: 12.5412
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0728 - mean_squared_error: 6.0728
# Epoch : 149 | score : 17 | best : 184 | 10 vs 7
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8650 - mean_squared_error: 1.8650
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7935 - mean_squared_error: 1.7935
# Epoch : 150 | score : 76 | best : 184 | 37 vs 39
# 1/1 [==============================] - 0s 3ms/step - loss: 9.7375 - mean_squared_error: 9.7375
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5277 - mean_squared_error: 4.5277
# Epoch : 151 | score : 189 | best : 184 | 101 vs 88
# 1/1 [==============================] - 0s 4ms/step - loss: 18.8239 - mean_squared_error: 18.8239
# 1/1 [==============================] - 0s 3ms/step - loss: 38.4376 - mean_squared_error: 38.4376
# Epoch : 152 | score : 75 | best : 189 | 39 vs 36
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0030 - mean_squared_error: 6.0030
# 1/1 [==============================] - 0s 5ms/step - loss: 10.1995 - mean_squared_error: 10.1995
# Epoch : 153 | score : 30 | best : 189 | 15 vs 15
# 1/1 [==============================] - 0s 5ms/step - loss: 10.0814 - mean_squared_error: 10.0814
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8981 - mean_squared_error: 7.8981
# Epoch : 154 | score : 99 | best : 189 | 48 vs 51
# 1/1 [==============================] - 0s 4ms/step - loss: 13.1222 - mean_squared_error: 13.1222
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6587 - mean_squared_error: 5.6587
# Epoch : 155 | score : 91 | best : 189 | 51 vs 40
# 1/1 [==============================] - 0s 4ms/step - loss: 16.7191 - mean_squared_error: 16.7191
# 1/1 [==============================] - 0s 4ms/step - loss: 49.4449 - mean_squared_error: 49.4449
# Epoch : 156 | score : 12 | best : 189 | 3 vs 9
# 1/1 [==============================] - 0s 6ms/step - loss: 9.3640 - mean_squared_error: 9.3640
# 1/1 [==============================] - 0s 4ms/step - loss: 11.6916 - mean_squared_error: 11.6916
# Epoch : 157 | score : 12 | best : 189 | 3 vs 9
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2896 - mean_squared_error: 3.2896
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9276 - mean_squared_error: 4.9276
# Epoch : 158 | score : 81 | best : 189 | 41 vs 40
# 1/1 [==============================] - 0s 3ms/step - loss: 18.0635 - mean_squared_error: 18.0635
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0718 - mean_squared_error: 3.0718
# Epoch : 159 | score : 111 | best : 189 | 60 vs 51
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2558 - mean_squared_error: 8.2558
# 1/1 [==============================] - 0s 3ms/step - loss: 22.5590 - mean_squared_error: 22.5590
# Epoch : 160 | score : 15 | best : 189 | 11 vs 4
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3127 - mean_squared_error: 4.3127
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8771 - mean_squared_error: 4.8771
# Epoch : 161 | score : 50 | best : 189 | 27 vs 23
# 1/1 [==============================] - 0s 5ms/step - loss: 26.4880 - mean_squared_error: 26.4880
# 1/1 [==============================] - 0s 3ms/step - loss: 20.8958 - mean_squared_error: 20.8958
# Epoch : 162 | score : 106 | best : 189 | 53 vs 53
# 1/1 [==============================] - 0s 3ms/step - loss: 27.8460 - mean_squared_error: 27.8460
# 1/1 [==============================] - 0s 5ms/step - loss: 15.8962 - mean_squared_error: 15.8962
# Epoch : 163 | score : 28 | best : 189 | 16 vs 12
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8966 - mean_squared_error: 2.8966
# 1/1 [==============================] - 0s 4ms/step - loss: 11.9564 - mean_squared_error: 11.9564
# Epoch : 164 | score : 39 | best : 189 | 21 vs 18
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5932 - mean_squared_error: 6.5932
# 1/1 [==============================] - 0s 3ms/step - loss: 14.4519 - mean_squared_error: 14.4519
# Epoch : 165 | score : 54 | best : 189 | 28 vs 26
# 1/1 [==============================] - 0s 3ms/step - loss: 13.9094 - mean_squared_error: 13.9094
# 1/1 [==============================] - 0s 3ms/step - loss: 15.0221 - mean_squared_error: 15.0221
# Epoch : 166 | score : 48 | best : 189 | 24 vs 24
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7462 - mean_squared_error: 7.7462
# 1/1 [==============================] - 0s 3ms/step - loss: 6.3230 - mean_squared_error: 6.3230
# Epoch : 167 | score : 81 | best : 189 | 40 vs 41
# 1/1 [==============================] - 0s 3ms/step - loss: 16.9264 - mean_squared_error: 16.9264
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4755 - mean_squared_error: 5.4755
# Epoch : 168 | score : 85 | best : 189 | 43 vs 42
# 1/1 [==============================] - 0s 4ms/step - loss: 40.0634 - mean_squared_error: 40.0634
# 1/1 [==============================] - 0s 3ms/step - loss: 28.5577 - mean_squared_error: 28.5577
# Epoch : 169 | score : 165 | best : 189 | 87 vs 78
# 1/1 [==============================] - 0s 3ms/step - loss: 25.8409 - mean_squared_error: 25.8409
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9585 - mean_squared_error: 3.9585
# Epoch : 170 | score : 11 | best : 189 | 4 vs 7
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5373 - mean_squared_error: 2.5373
# 1/1 [==============================] - 0s 3ms/step - loss: 7.8237 - mean_squared_error: 7.8237
# Epoch : 171 | score : 152 | best : 189 | 76 vs 76
# 1/1 [==============================] - 0s 3ms/step - loss: 24.5592 - mean_squared_error: 24.5592
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7038 - mean_squared_error: 3.7038
# Epoch : 172 | score : 63 | best : 189 | 32 vs 31
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6997 - mean_squared_error: 9.6997
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2927 - mean_squared_error: 7.2927
# Epoch : 173 | score : 19 | best : 189 | 10 vs 9
# 1/1 [==============================] - 0s 12ms/step - loss: 6.4584 - mean_squared_error: 6.4584
# 1/1 [==============================] - 0s 4ms/step - loss: 4.3998 - mean_squared_error: 4.3998
# Epoch : 174 | score : 11 | best : 189 | 7 vs 4
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2639 - mean_squared_error: 7.2639
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8847 - mean_squared_error: 5.8847
# Epoch : 175 | score : 15 | best : 189 | 4 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5403 - mean_squared_error: 2.5403
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7427 - mean_squared_error: 1.7427
# Epoch : 176 | score : 11 | best : 189 | 7 vs 4
# 1/1 [==============================] - 0s 3ms/step - loss: 2.6630 - mean_squared_error: 2.6630
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7334 - mean_squared_error: 1.7334
# Epoch : 177 | score : 47 | best : 189 | 21 vs 26
# 1/1 [==============================] - 0s 3ms/step - loss: 27.5504 - mean_squared_error: 27.5504
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2172 - mean_squared_error: 3.2172
# Epoch : 178 | score : 55 | best : 189 | 29 vs 26
# 1/1 [==============================] - 0s 4ms/step - loss: 1.8649 - mean_squared_error: 1.8649
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7661 - mean_squared_error: 7.7661
# Epoch : 179 | score : 14 | best : 189 | 9 vs 5
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6876 - mean_squared_error: 1.6876
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2108 - mean_squared_error: 1.2108
# Epoch : 180 | score : 212 | best : 189 | 111 vs 101
# 1/1 [==============================] - 0s 3ms/step - loss: 14.2304 - mean_squared_error: 14.2304
# 1/1 [==============================] - 0s 3ms/step - loss: 43.0108 - mean_squared_error: 43.0108
# Epoch : 181 | score : 51 | best : 212 | 25 vs 26
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7006 - mean_squared_error: 9.7006
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2805 - mean_squared_error: 7.2805
# Epoch : 182 | score : 158 | best : 212 | 85 vs 73
# 1/1 [==============================] - 0s 3ms/step - loss: 13.9289 - mean_squared_error: 13.9289
# 1/1 [==============================] - 0s 4ms/step - loss: 93.7194 - mean_squared_error: 93.7194
# Epoch : 183 | score : 44 | best : 212 | 24 vs 20
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1882 - mean_squared_error: 7.1882
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2993 - mean_squared_error: 9.2993
# Epoch : 184 | score : 206 | best : 212 | 106 vs 100
# 1/1 [==============================] - 0s 4ms/step - loss: 13.0812 - mean_squared_error: 13.0812
# 1/1 [==============================] - 0s 4ms/step - loss: 13.1083 - mean_squared_error: 13.1083
# Epoch : 185 | score : 40 | best : 212 | 17 vs 23
# 1/1 [==============================] - 0s 3ms/step - loss: 24.5976 - mean_squared_error: 24.5976
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8692 - mean_squared_error: 4.8692
# Epoch : 186 | score : 42 | best : 212 | 25 vs 17
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3104 - mean_squared_error: 4.3104
# 1/1 [==============================] - 0s 3ms/step - loss: 14.6020 - mean_squared_error: 14.6020
# Epoch : 187 | score : 20 | best : 212 | 7 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0751 - mean_squared_error: 2.0751
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3797 - mean_squared_error: 5.3797
# Epoch : 188 | score : 27 | best : 212 | 15 vs 12
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9686 - mean_squared_error: 3.9686
# 1/1 [==============================] - 0s 3ms/step - loss: 8.2861 - mean_squared_error: 8.2861
# Epoch : 189 | score : 56 | best : 212 | 27 vs 29
# 1/1 [==============================] - 0s 5ms/step - loss: 19.2188 - mean_squared_error: 19.2188
# 1/1 [==============================] - 0s 4ms/step - loss: 24.2669 - mean_squared_error: 24.2669
# Epoch : 190 | score : 184 | best : 212 | 93 vs 91
# 1/1 [==============================] - 0s 3ms/step - loss: 19.7432 - mean_squared_error: 19.7432
# 1/1 [==============================] - 0s 3ms/step - loss: 11.9622 - mean_squared_error: 11.9622
# Epoch : 191 | score : 69 | best : 212 | 35 vs 34
# 1/1 [==============================] - 0s 4ms/step - loss: 25.8833 - mean_squared_error: 25.8833
# 1/1 [==============================] - 0s 4ms/step - loss: 12.6389 - mean_squared_error: 12.6389
# Epoch : 192 | score : 85 | best : 212 | 46 vs 39
# 1/1 [==============================] - 0s 3ms/step - loss: 11.8090 - mean_squared_error: 11.8090
# 1/1 [==============================] - 0s 3ms/step - loss: 10.8576 - mean_squared_error: 10.8576
# Epoch : 193 | score : 183 | best : 212 | 97 vs 86
# 1/1 [==============================] - 0s 3ms/step - loss: 22.6342 - mean_squared_error: 22.6342
# 1/1 [==============================] - 0s 4ms/step - loss: 63.3294 - mean_squared_error: 63.3294
# Epoch : 194 | score : 20 | best : 212 | 9 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1068 - mean_squared_error: 7.1068
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4233 - mean_squared_error: 2.4233
# Epoch : 195 | score : 102 | best : 212 | 52 vs 50
# 1/1 [==============================] - 0s 3ms/step - loss: 22.2733 - mean_squared_error: 22.2733
# 1/1 [==============================] - 0s 3ms/step - loss: 18.5994 - mean_squared_error: 18.5994
# Epoch : 196 | score : 90 | best : 212 | 43 vs 47
# 1/1 [==============================] - 0s 3ms/step - loss: 36.5717 - mean_squared_error: 36.5717
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0236 - mean_squared_error: 4.0236
# Epoch : 197 | score : 117 | best : 212 | 64 vs 53
# 1/1 [==============================] - 0s 4ms/step - loss: 8.5268 - mean_squared_error: 8.5268
# 1/1 [==============================] - 0s 3ms/step - loss: 47.0855 - mean_squared_error: 47.0855
# Epoch : 198 | score : 29 | best : 212 | 11 vs 18
# 1/1 [==============================] - 0s 3ms/step - loss: 24.6124 - mean_squared_error: 24.6124
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6566 - mean_squared_error: 7.6566
# Epoch : 199 | score : 24 | best : 212 | 12 vs 12
# ...
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6469 - mean_squared_error: 6.6469
# Epoch : 434 | score : 32 | best : 300 | 14 vs 18
# 1/1 [==============================] - 0s 3ms/step - loss: 9.6732 - mean_squared_error: 9.6732
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4683 - mean_squared_error: 3.4683
# Epoch : 435 | score : 107 | best : 300 | 55 vs 52
# 1/1 [==============================] - 0s 4ms/step - loss: 10.4581 - mean_squared_error: 10.4581
# 1/1 [==============================] - 0s 4ms/step - loss: 7.8212 - mean_squared_error: 7.8212
# Epoch : 436 | score : 13 | best : 300 | 8 vs 5
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5640 - mean_squared_error: 5.5640
# 1/1 [==============================] - 0s 4ms/step - loss: 4.7396 - mean_squared_error: 4.7396
# Epoch : 437 | score : 8 | best : 300 | 6 vs 2
# 1/1 [==============================] - 0s 4ms/step - loss: 11.1471 - mean_squared_error: 11.1471
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4890 - mean_squared_error: 0.4890
# Epoch : 438 | score : 24 | best : 300 | 10 vs 14
# 1/1 [==============================] - 0s 4ms/step - loss: 14.7360 - mean_squared_error: 14.7360
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9552 - mean_squared_error: 8.9552
# Epoch : 439 | score : 24 | best : 300 | 8 vs 16
# 1/1 [==============================] - 0s 5ms/step - loss: 14.9527 - mean_squared_error: 14.9527
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0438 - mean_squared_error: 4.0438
# Epoch : 440 | score : 58 | best : 300 | 31 vs 27
# 1/1 [==============================] - 0s 4ms/step - loss: 32.9849 - mean_squared_error: 32.9849
# 1/1 [==============================] - 0s 4ms/step - loss: 21.3061 - mean_squared_error: 21.3061
# Epoch : 441 | score : 16 | best : 300 | 8 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 16.4507 - mean_squared_error: 16.4507
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6317 - mean_squared_error: 5.6317
# Epoch : 442 | score : 16 | best : 300 | 10 vs 6
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0131 - mean_squared_error: 2.0131
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4017 - mean_squared_error: 1.4017
# Epoch : 443 | score : 81 | best : 300 | 44 vs 37
# 1/1 [==============================] - 0s 4ms/step - loss: 11.2763 - mean_squared_error: 11.2763
# 1/1 [==============================] - 0s 4ms/step - loss: 22.3198 - mean_squared_error: 22.3198
# Epoch : 444 | score : 14 | best : 300 | 6 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 2.9815 - mean_squared_error: 2.9815
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8644 - mean_squared_error: 6.8644
# Epoch : 445 | score : 27 | best : 300 | 11 vs 16
# 1/1 [==============================] - 0s 3ms/step - loss: 14.2652 - mean_squared_error: 14.2652
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5292 - mean_squared_error: 5.5292
# Epoch : 446 | score : 15 | best : 300 | 5 vs 10
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6820 - mean_squared_error: 6.6820
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9150 - mean_squared_error: 9.9150
# Epoch : 447 | score : 30 | best : 300 | 15 vs 15
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9375 - mean_squared_error: 4.9375
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9506 - mean_squared_error: 4.9506
# Epoch : 448 | score : 29 | best : 300 | 11 vs 18
# 1/1 [==============================] - 0s 4ms/step - loss: 30.1179 - mean_squared_error: 30.1179
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4096 - mean_squared_error: 2.4096
# Epoch : 449 | score : 34 | best : 300 | 17 vs 17
# 1/1 [==============================] - 0s 4ms/step - loss: 19.2949 - mean_squared_error: 19.2949
# 1/1 [==============================] - 0s 4ms/step - loss: 16.0733 - mean_squared_error: 16.0733
# Epoch : 450 | score : 29 | best : 300 | 12 vs 17
# 1/1 [==============================] - 0s 4ms/step - loss: 33.4917 - mean_squared_error: 33.4917
# 1/1 [==============================] - 0s 4ms/step - loss: 12.7714 - mean_squared_error: 12.7714
# Epoch : 451 | score : 27 | best : 300 | 14 vs 13
# 1/1 [==============================] - 0s 4ms/step - loss: 26.8470 - mean_squared_error: 26.8470
# 1/1 [==============================] - 0s 15ms/step - loss: 10.3737 - mean_squared_error: 10.3737
# Epoch : 452 | score : 62 | best : 300 | 33 vs 29
# 1/1 [==============================] - 0s 3ms/step - loss: 17.8184 - mean_squared_error: 17.8184
# 1/1 [==============================] - 0s 4ms/step - loss: 13.0565 - mean_squared_error: 13.0565
# Epoch : 453 | score : 31 | best : 300 | 15 vs 16
# 1/1 [==============================] - 0s 4ms/step - loss: 44.5702 - mean_squared_error: 44.5702
# 1/1 [==============================] - 0s 4ms/step - loss: 13.8101 - mean_squared_error: 13.8101
# Epoch : 454 | score : 19 | best : 300 | 10 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8084 - mean_squared_error: 3.8084
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6684 - mean_squared_error: 6.6684
# Epoch : 455 | score : 18 | best : 300 | 10 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8746 - mean_squared_error: 2.8746
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0941 - mean_squared_error: 4.0941
# Epoch : 456 | score : 29 | best : 300 | 14 vs 15
# 1/1 [==============================] - 0s 4ms/step - loss: 15.8459 - mean_squared_error: 15.8459
# 1/1 [==============================] - 0s 4ms/step - loss: 10.3473 - mean_squared_error: 10.3473
# Epoch : 457 | score : 29 | best : 300 | 15 vs 14
# 1/1 [==============================] - 0s 4ms/step - loss: 7.7573 - mean_squared_error: 7.7573
# 1/1 [==============================] - 0s 4ms/step - loss: 7.3774 - mean_squared_error: 7.3774
# Epoch : 458 | score : 32 | best : 300 | 14 vs 18
# 1/1 [==============================] - 0s 3ms/step - loss: 26.1721 - mean_squared_error: 26.1721
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7838 - mean_squared_error: 3.7838
# Epoch : 459 | score : 53 | best : 300 | 28 vs 25
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4090 - mean_squared_error: 7.4090
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0320 - mean_squared_error: 6.0320
# Epoch : 460 | score : 41 | best : 300 | 23 vs 18
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4610 - mean_squared_error: 5.4610
# 1/1 [==============================] - 0s 4ms/step - loss: 12.0234 - mean_squared_error: 12.0234
# Epoch : 461 | score : 69 | best : 300 | 41 vs 28
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7776 - mean_squared_error: 7.7776
# 1/1 [==============================] - 0s 3ms/step - loss: 63.5912 - mean_squared_error: 63.5912
# Epoch : 462 | score : 80 | best : 300 | 41 vs 39
# 1/1 [==============================] - 0s 3ms/step - loss: 9.7125 - mean_squared_error: 9.7125
# 1/1 [==============================] - 0s 4ms/step - loss: 3.9259 - mean_squared_error: 3.9259
# Epoch : 463 | score : 12 | best : 300 | 4 vs 8
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0717 - mean_squared_error: 2.0717
# 1/1 [==============================] - 0s 4ms/step - loss: 6.2086 - mean_squared_error: 6.2086
# Epoch : 464 | score : 19 | best : 300 | 9 vs 10
# 1/1 [==============================] - 0s 4ms/step - loss: 7.4292 - mean_squared_error: 7.4292
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8593 - mean_squared_error: 3.8593
# Epoch : 465 | score : 30 | best : 300 | 14 vs 16
# 1/1 [==============================] - 0s 3ms/step - loss: 7.5863 - mean_squared_error: 7.5863
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8231 - mean_squared_error: 1.8231
# Epoch : 466 | score : 104 | best : 300 | 51 vs 53
# 1/1 [==============================] - 0s 3ms/step - loss: 15.2705 - mean_squared_error: 15.2705
# 1/1 [==============================] - 0s 4ms/step - loss: 9.0246 - mean_squared_error: 9.0246
# Epoch : 467 | score : 17 | best : 300 | 10 vs 7
# 1/1 [==============================] - 0s 3ms/step - loss: 16.8137 - mean_squared_error: 16.8137
# 1/1 [==============================] - 0s 4ms/step - loss: 10.7352 - mean_squared_error: 10.7352
# Epoch : 468 | score : 93 | best : 300 | 54 vs 39
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7041 - mean_squared_error: 8.7041
# 1/1 [==============================] - 0s 4ms/step - loss: 55.3469 - mean_squared_error: 55.3469
# Epoch : 469 | score : 39 | best : 300 | 21 vs 18
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2903 - mean_squared_error: 7.2903
# 1/1 [==============================] - 0s 4ms/step - loss: 12.9437 - mean_squared_error: 12.9437
# Epoch : 470 | score : 39 | best : 300 | 19 vs 20
# 1/1 [==============================] - 0s 3ms/step - loss: 11.2636 - mean_squared_error: 11.2636
# 1/1 [==============================] - 0s 3ms/step - loss: 12.4414 - mean_squared_error: 12.4414
# Epoch : 471 | score : 39 | best : 300 | 18 vs 21
# 1/1 [==============================] - 0s 3ms/step - loss: 38.8495 - mean_squared_error: 38.8495
# 1/1 [==============================] - 0s 3ms/step - loss: 14.7373 - mean_squared_error: 14.7373
# Epoch : 472 | score : 9 | best : 300 | 1 vs 8
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1807 - mean_squared_error: 0.1807
# 1/1 [==============================] - 0s 3ms/step - loss: 10.3312 - mean_squared_error: 10.3312
# Epoch : 473 | score : 92 | best : 300 | 48 vs 44
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3996 - mean_squared_error: 5.3996
# 1/1 [==============================] - 0s 4ms/step - loss: 6.4448 - mean_squared_error: 6.4448
# Epoch : 474 | score : 28 | best : 300 | 14 vs 14
# 1/1 [==============================] - 0s 3ms/step - loss: 11.3217 - mean_squared_error: 11.3217
# 1/1 [==============================] - 0s 3ms/step - loss: 16.3841 - mean_squared_error: 16.3841
# Epoch : 475 | score : 103 | best : 300 | 57 vs 46
# 1/1 [==============================] - 0s 4ms/step - loss: 11.1347 - mean_squared_error: 11.1347
# 1/1 [==============================] - 0s 4ms/step - loss: 25.9781 - mean_squared_error: 25.9781
# Epoch : 476 | score : 59 | best : 300 | 31 vs 28
# 1/1 [==============================] - 0s 3ms/step - loss: 7.2511 - mean_squared_error: 7.2511
# 1/1 [==============================] - 0s 4ms/step - loss: 10.9697 - mean_squared_error: 10.9697
# Epoch : 477 | score : 38 | best : 300 | 19 vs 19
# 1/1 [==============================] - 0s 4ms/step - loss: 10.3595 - mean_squared_error: 10.3595
# 1/1 [==============================] - 0s 3ms/step - loss: 30.3618 - mean_squared_error: 30.3618
# Epoch : 478 | score : 45 | best : 300 | 21 vs 24
# 1/1 [==============================] - 0s 3ms/step - loss: 19.6231 - mean_squared_error: 19.6231
# 1/1 [==============================] - 0s 3ms/step - loss: 14.4294 - mean_squared_error: 14.4294
# Epoch : 479 | score : 56 | best : 300 | 30 vs 26
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3382 - mean_squared_error: 9.3382
# 1/1 [==============================] - 0s 3ms/step - loss: 10.8648 - mean_squared_error: 10.8648
# Epoch : 480 | score : 14 | best : 300 | 5 vs 9
# 1/1 [==============================] - 0s 4ms/step - loss: 2.6838 - mean_squared_error: 2.6838
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8597 - mean_squared_error: 3.8597
# Epoch : 481 | score : 19 | best : 300 | 8 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8651 - mean_squared_error: 4.8651
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6764 - mean_squared_error: 3.6764
# Epoch : 482 | score : 205 | best : 300 | 106 vs 99
# 1/1 [==============================] - 0s 4ms/step - loss: 31.8867 - mean_squared_error: 31.8867
# 1/1 [==============================] - 0s 4ms/step - loss: 18.1549 - mean_squared_error: 18.1549
# Epoch : 483 | score : 76 | best : 300 | 38 vs 38
# 1/1 [==============================] - 0s 3ms/step - loss: 14.4199 - mean_squared_error: 14.4199
# 1/1 [==============================] - 0s 3ms/step - loss: 8.9978 - mean_squared_error: 8.9978
# Epoch : 484 | score : 86 | best : 300 | 40 vs 46
# 1/1 [==============================] - 0s 3ms/step - loss: 57.8596 - mean_squared_error: 57.8596
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5272 - mean_squared_error: 2.5272
# Epoch : 485 | score : 66 | best : 300 | 33 vs 33
# 1/1 [==============================] - 0s 3ms/step - loss: 13.4244 - mean_squared_error: 13.4244
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7577 - mean_squared_error: 6.7577
# Epoch : 486 | score : 8 | best : 300 | 6 vs 2
# 1/1 [==============================] - 0s 3ms/step - loss: 16.7517 - mean_squared_error: 16.7517
# 1/1 [==============================] - 0s 16ms/step - loss: 0.9761 - mean_squared_error: 0.9761
# Epoch : 487 | score : 64 | best : 300 | 35 vs 29
# 1/1 [==============================] - 0s 3ms/step - loss: 9.4492 - mean_squared_error: 9.4492
# 1/1 [==============================] - 0s 3ms/step - loss: 6.4835 - mean_squared_error: 6.4835
# Epoch : 488 | score : 97 | best : 300 | 54 vs 43
# 1/1 [==============================] - 0s 4ms/step - loss: 26.7822 - mean_squared_error: 26.7822
# 1/1 [==============================] - 0s 3ms/step - loss: 35.8517 - mean_squared_error: 35.8517
# Epoch : 489 | score : 17 | best : 300 | 8 vs 9
# 1/1 [==============================] - 0s 3ms/step - loss: 18.7514 - mean_squared_error: 18.7514
# 1/1 [==============================] - 0s 3ms/step - loss: 10.2910 - mean_squared_error: 10.2910
# Epoch : 490 | score : 110 | best : 300 | 52 vs 58
# 1/1 [==============================] - 0s 4ms/step - loss: 51.6402 - mean_squared_error: 51.6402
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6578 - mean_squared_error: 1.6578
# Epoch : 491 | score : 43 | best : 300 | 18 vs 25
# 1/1 [==============================] - 0s 3ms/step - loss: 26.9328 - mean_squared_error: 26.9328
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5657 - mean_squared_error: 5.5657
# Epoch : 492 | score : 38 | best : 300 | 20 vs 18
# 1/1 [==============================] - 0s 4ms/step - loss: 10.0106 - mean_squared_error: 10.0106
# 1/1 [==============================] - 0s 4ms/step - loss: 9.3725 - mean_squared_error: 9.3725
# Epoch : 493 | score : 17 | best : 300 | 9 vs 8
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1665 - mean_squared_error: 5.1665
# 1/1 [==============================] - 0s 4ms/step - loss: 3.2936 - mean_squared_error: 3.2936
# Epoch : 494 | score : 137 | best : 300 | 69 vs 68
# 1/1 [==============================] - 0s 4ms/step - loss: 14.5529 - mean_squared_error: 14.5529
# 1/1 [==============================] - 0s 4ms/step - loss: 10.9889 - mean_squared_error: 10.9889
# Epoch : 495 | score : 152 | best : 300 | 81 vs 71
# 1/1 [==============================] - 0s 4ms/step - loss: 6.6097 - mean_squared_error: 6.6097
# 1/1 [==============================] - 0s 4ms/step - loss: 31.3808 - mean_squared_error: 31.3808
# Epoch : 496 | score : 27 | best : 300 | 14 vs 13
# 1/1 [==============================] - 0s 3ms/step - loss: 43.5224 - mean_squared_error: 43.5224
# 1/1 [==============================] - 0s 3ms/step - loss: 45.7083 - mean_squared_error: 45.7083
# Epoch : 497 | score : 87 | best : 300 | 46 vs 41
# 1/1 [==============================] - 0s 3ms/step - loss: 7.4835 - mean_squared_error: 7.4835
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7040 - mean_squared_error: 7.7040
# Epoch : 498 | score : 37 | best : 300 | 17 vs 20
# 1/1 [==============================] - 0s 3ms/step - loss: 20.8353 - mean_squared_error: 20.8353
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8482 - mean_squared_error: 2.8482
# Epoch : 499 | score : 14 | best : 300 | 3 vs 11
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5462 - mean_squared_error: 1.5462
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8521 - mean_squared_error: 4.8521

# %%
new_state = env.reset().reshape([-1,4])
print(model0(new_state).numpy())
print(model1(new_state).numpy())
print(model0.get_weights())
# Out:
# [[45.460842]]
# [[11.589589]]
# [array([[-0.19199362, -0.79946697,  0.35423177,  0.37033904,  0.57396024],
#        [ 1.2549629 ,  0.47474214,  0.9743056 ,  0.6592582 ,  1.0227792 ],
#        [ 0.9113481 ,  0.51702064,  0.5590204 , -0.12086061,  0.70064634],
#        [-0.35446692, -0.05711846,  0.49514034, -2.084933  , -0.45837846]],
#       dtype=float32), array([ 1.3453412,  0.8679711,  1.0537301, -0.9916672,  1.8024334],
#       dtype=float32), array([[-0.3329887 ,  1.2293314 , -0.50693804,  0.6815692 , -0.13374008,
#         -0.028402  , -0.38363907,  1.2468998 , -0.2930184 , -0.25176623],
#        [ 0.41041186,  0.8126293 ,  0.2526903 , -0.29210514,  0.38200143,
#         -0.44016987, -0.4187584 ,  0.7218626 , -0.50769883, -0.41984132],
#        [ 0.68241036,  0.55315006, -0.02615865,  0.20306334,  0.1270867 ,
#         -0.71339947,  0.5021563 ,  1.0020087 , -0.55876654, -0.33553186],
#        [ 0.00412283, -0.65956455,  0.24245855, -0.09576132, -0.60158145,
#          0.3746137 ,  0.5595936 , -1.8806552 , -0.47761333, -0.10432528],
#        [-0.43581843,  0.8046455 , -0.03633979,  0.31739366, -0.22260645,
#          0.55478066,  0.11464739,  1.9202018 ,  0.06613054,  0.5150853 ]],
#       dtype=float32), array([ 0.05176224,  1.0735658 , -0.00392276,  0.67896205,  0.05125201,
#        -0.1140267 , -0.03098389,  2.139984  ,  0.01800513, -0.02645272],
#       dtype=float32), array([[-0.8634462 ],
#        [ 1.9852816 ],
#        [-0.13271168],
#        [ 0.8588415 ],
#        [-0.41486675],
#        [-0.89566666],
#        [-0.49886128],
#        [ 3.557001  ],
#        [ 0.4950112 ],
#        [-0.38747075]], dtype=float32), array([1.7684674], dtype=float32)]

# %%
model0_state[-1 * np.min([10,num_action[0]]):]
# Out:
# 8
